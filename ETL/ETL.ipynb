# %%
import pandas as pd

# %%
Coffee =  pd.read_csv("/Users/ASUS/Desktop/BI_Final/Data/salesAll.csv")

# %%
Coffee
# Out:
#                Custom Time  customer_id  Dim_customer.Year  \
# 0      1899-12-30 11:00:00         8600               1983
# 1      1899-12-30 11:00:00         8600               1983
# 2      1899-12-30 17:00:00         8600               1983
# 3      1899-12-30 17:00:00         8600               1983
# 4      1899-12-30 19:00:00         8059               1964
# ...                    ...          ...                ...
# 29995  1899-12-30 18:00:00         6000               1983
# 29996  1899-12-30 18:00:00         6000               1983
# 29997  1899-12-30 18:00:00         6000               1983
# 29998  1899-12-30 18:00:00         6000               1983
# 29999  1899-12-30 18:00:00         6000               1983
#
#       Dim_product.product_category              gener  product_id  \
# 0                           Bakery  Older Millennials          72
# 1                           Coffee  Older Millennials          87
# ...

# %%
Coffee['customer_id'] = Coffee['customer_id'].astype('string')

# %%
Coffee['customer_transaction_id'] = Coffee['customer_id'] + '-' + Coffee['transaction_date']
Coffee
# Out:
#                Custom Time customer_id  Dim_customer.Year  \
# 0      1899-12-30 11:00:00        8600               1983
# 1      1899-12-30 11:00:00        8600               1983
# 2      1899-12-30 17:00:00        8600               1983
# 3      1899-12-30 17:00:00        8600               1983
# 4      1899-12-30 19:00:00        8059               1964
# ...                    ...         ...                ...
# 29995  1899-12-30 18:00:00        6000               1983
# 29996  1899-12-30 18:00:00        6000               1983
# 29997  1899-12-30 18:00:00        6000               1983
# 29998  1899-12-30 18:00:00        6000               1983
# 29999  1899-12-30 18:00:00        6000               1983
#
#       Dim_product.product_category              gener  product_id  \
# 0                           Bakery  Older Millennials          72
# 1                           Coffee  Older Millennials          87
# 2                           Bakery  Older Millennials          72
# ...

# %%
Coffee.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 17 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Custom Time                   30000 non-null  object
#  1   customer_id                   30000 non-null  string
#  2   Dim_customer.Year             30000 non-null  int64
#  3   Dim_product.product_category  30000 non-null  object
#  4   gener                         30000 non-null  object
#  5   product_id                    30000 non-null  int64
#  6   promo_item_yn                 30000 non-null  object
#  7   quantity_sold                 30000 non-null  int64
#  8   Sales                         30000 non-null  float64
#  9   staff_id                      30000 non-null  int64
#  10  store_id                      30000 non-null  int64
#  11  Thế Hệ                        30000 non-null  int64
# ...
